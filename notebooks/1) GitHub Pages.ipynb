# %% [markdown]
# # GitHub Pages

# %% [markdown]
# ![image.png](attachment:image.png)
#
# <p>GitHub Pages is a static site hosting service that takes HTML, CSS, and JavaScript files straight from a repository on GitHub, optionally runs the files through a build process, and publishes a website.</p> [1]
#
# You can visit my deployed site, which is running an instance of JupyterLite lab <a href="https://cianhession.github.io/Emerging_Technologies/">here</a>
#
# In order to create your own user site, you will need to create a new repository on your GitHub account and call this repo USERNAME.github.io, this will let GitHub identify this repo as a user site to be deployed, if you direct from root to for example: <i>CianHession.github.io/SampleRepo</i> it will contain the contents of this repo <i>Sample Repo</i> on the site.
#
# You can statically build your own site or by using a custom premade build
# ***

# %% [markdown]
# ## HTTP

# %% [markdown]
# HTTP or Hypertext Transfer Protocol is the most common way to implement communication between a server and a client.
# Think of your browser as the client and when you search for a website and get onto the site, this being a response from the server which we cannot see, but know it is working in the background.
#
# Given HTTP is a classic server-client model, this means the client opens connection with a request and must wait until a response is sent back, HTTP is also refered to as being stateless, meaning the server does not save data from any requests.
# The client also cannot make any new requests until the request(s) before are all responded too.
#
# The requests are sent by HTTP Headers, they contain fields such as METHOD, RESPONSE and more.
# I recommend clicking
# <a href="https://www.w3.org/Protocols/rfc2616/rfc2616-sec6.html">here</a>  [2] to read about the response codes, as certain codes such as 404 is an error response, in particular a "not found" error, indicating this page is not valid on a site.
#
# ![image.png](attachment:image.png)
# Image found at: https://bytesofgigabytes.com/IMAGES/Networking/HTTPcommuncation/http%20communication.png

# %% [markdown]
# ***
# ### Sample Request

# %% [markdown]
# ```
# POST /contact_form.php HTTP/1.1
# Host: developer.mozilla.org
# Content-Length: 64
# Content-Type: application/x-www-form-urlencoded
#
# name=Joe%20User&request=Send%20me%20one%20of%20your%20catalogue
# ```
# As we can see from above, this is a POST request, this is just a regular search.
# The Host Header is the website we are requesting from.
#
# The name = is the data we are searching for converted into header format.

# %% [markdown]
# ***
# ### Sample Response

# %% [markdown]
# ``
# HTTP/1.1 200 OK
# Content-Type: text/html; charset=utf-8
# Content-Length: 55743
# Connection: keep-alive
# Cache-Control: s-maxage=300, public, max-age=0
# Content-Language: en-US
# Date: Thu, 06 Dec 2018 17:37:18 GMT
# ETag: "2e77ad1dc6ab0b53a2996dfd4653c1c3"
# Server: meinheld/0.6.1
# Strict-Transport-Security: max-age=63072000
# X-Content-Type-Options: nosniff
# X-Frame-Options: DENY
# X-XSS-Protection: 1; mode=block
# Vary: Accept-Encoding,Cookie
# Age: 7
# ``
#
# ***

# %% [markdown]
# ## GitHub Actions

# %% [markdown]
# In more recent times developers have favoured the ability of continous integration and delivery at once. It is favoured as it allows testing of code as soon as it is pushed to GitHub. GitHub actions allows the developer(s) to know if the code that is currently pushed is working it is indicated by a green tick or else a red x which upon clicking will provide detailed information as to why the code is not working.
#
# Below is a screenshot from my GitHub repo for this Project, as you can see it is working correctly and a green tick is displayed
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Static vs Dynamic
# ***

# %% [markdown]
# A website can be one of two states; Static or Dynamic, each provide different functionality for the site.
# When we say Dynamic or Static this is how the content of the website is to be shown/produced.
#
# A static website are more old fashioned websites, but still used. Static websites do not change or be affected upon user inputs, usually the site is just html and css and has a set number of pages all of a set layout
#
# A dynamic website provides far more functionality and can in real time fetch changes which can occur from user input, for example, if a user entered data into a forum, it can immediately return the data without requring a refresh and or re-compiling the entirity of the site to apply changes, as dynamic websites pull and store data in other pages and can use these pages at any time
#
# <img src="https://kfg6bckb.media.zestyio.com/What-can-be-Static-or-Dynamic_.png"></img>
#
# Image provided from https://kfg6bckb.media.zestyio.com/What-can-be-Static-or-Dynamic_.png
# ***

# %% [markdown]
# ## References

# %% [markdown]
# [1] https://docs.github.com/en/pages/getting-started-with-github-pages/about-github-pages <br>
# [2] https://www.w3.org/Protocols/rfc2616/rfc2616-sec6.html
